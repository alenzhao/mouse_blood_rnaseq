# %% [markdown]
# ## DE with voom limma
# * rsem expected counts are used

# %%
require("edgeR")
require("limma")
library(readr)
require(tximport)
DATA = '../data/'
# Out:
# Loading required package: edgeR
# Loading required package: limma

# %%
# from https://github.com/mikelove/tximport/blob/master/vignettes/tximport.md#rsem
labels = c('g1eer4.1', 'g1eer4.2', 'mel.1', 'mel.2', 'eryth.1', 'eryth.2',
           'adrenal.1', 'adrenal.2', 'thymus.1', 'thymus.2')
files <- file.path(DATA, "countsForTximport", paste0(labels, ".tsv"))
names(files) <- labels
txi.rsem <- tximport(files, type = "rsem", reader = read_tsv)
# Out:
# reading in files
# 1 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 2 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 3 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 4 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 5 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 6 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 7 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 8 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 9 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )
# 10 Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double(),
#   posterior_mean_count = col_double(),
#   posterior_standard_deviation_of_count = col_double(),
#   pme_TPM = col_double(),
#   pme_FPKM = col_double(),
#   TPM_ci_lower_bound = col_double(),
#   TPM_ci_upper_bound = col_double(),
#   FPKM_ci_lower_bound = col_double(),
#   FPKM_ci_upper_bound = col_double()
# )

# %%
# rm rows with all low expressed genes
flag = apply(txi.rsem$counts, 1, max)>50
useMpre = txi.rsem$counts[flag,]
flag = apply(useMpre, 1, min)>10
useM = useMpre[flag,]

# %%
dim(txi.rsem$counts)
# Out:
# [1] 30433    10

# %%
dim(useM)
# Out:
# [1] 7600   10

# %%
# abundance is fpkm
# counts is expected count
# need to filter low!

# %%
log(300+.5, 2)
# Out:
# [1] 8.231221

# %%
y <- DGEList(counts=as.matrix(useM), genes=rownames(useM))
y <- calcNormFactors(y)

# %%
# condition = factor(rep(c("A", "B"), each = 3)))
m=c('g1eer4','g1eer4','mel','mel','eryth', 'eryth', 'adrenal', 'adrenal', 'thymus', 'thymus')
design <- model.matrix(~factor(m))
print(design)
# Out:
#    (Intercept) factor(m)eryth factor(m)g1eer4 factor(m)mel factor(m)thymus
# 1            1              0               1            0               0
# 2            1              0               1            0               0
# 3            1              0               0            1               0
# 4            1              0               0            1               0
# 5            1              1               0            0               0
# 6            1              1               0            0               0
# 7            1              0               0            0               0
# 8            1              0               0            0               0
# 9            1              0               0            0               1
# 10           1              0               0            0               1
# attr(,"assign")
# [1] 0 1 1 1 1
# attr(,"contrasts")
# attr(,"contrasts")$`factor(m)`
# [1] "contr.treatment"

# %%
#targets = data.frame()
#colnames()
#design <- model.matrix(~as.factor(labels))
#print(design)
v <- voom(y, design, plot=TRUE);
voomData <- v$E
# Out:
# Plot with title “voom: Mean-variance trend”

# %%
#Run linear fit and Create the contrast
design <- model.matrix(~0+factor(m))
colnames(design) <- c('g1eer4', 'mel', 'eryth', 'adrenal')
fit <- lmFit(voomData, design)

# %%
contrast.matrix <- makeContrasts(bloodDiff="g1eer4-mel",
                                 ga="g1eer4-adrenal",
                                 ma="mel-adrenal",
                                 eq="eryth-adrenal",
                                 levels=design)
fit2 <- contrasts.fit(fit, contrast.matrix)
fit2 <- eBayes(fit2)

#Okay now combine all into one result data frame
#myComps <- colnames(fit2$contrasts);

# %%
myComps <- colnames(fit2$contrasts)
output <- topTable(fit2, number=60000)
genOutput <- output[,c("logFC", "P.Value")];
AllResult <- list(genOutput, output, voomData, design, myComps);
names(AllResult) <- c("effectPval", "fullResult", "voomMatrix", "design", "comparison")

# %%
mycol=c("red", "red", "blue", "blue", "green", "green", 'purple', 'purple', 'orange', 'orange')
plotMDS(v, top=50, labels=labels, col=mycol, gene.selection="common")
# Out:
# plot without title
